# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
import sklearn as skl
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df["credit_ranking"]

# Display a sample of y
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop("credit_ranking", axis="columns")

# Review the features DataFrame
X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.20, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
X_scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_scaler.fit(X_train)

# Fit the scaler to the features training dataset
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
(X_train_scaled[0])
# Out:
# array([ 0.43167779, -0.58647242,  0.34980914, -0.09649612, -0.15614007,
#         0.97993527,  1.15931223,  1.01509288,  0.3564837 , -0.20899866,
#        -0.92958418])

# %%
# Define the the number of inputs (features) to the model
number_input_features = len(X_train_scaled[0])

# Review the number of features
print(f'Number of input features: ',number_input_features)
# Out:
# Number of input features:  11

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1 =  11

# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2 = 5

## Define the number of hidden nodes for the third hidden layer
#hidden_nodes_layer3 = 3

# Define the number of neurons in the output layer
output_neurons = 1

# %%
# Create the Sequential model instance
nn= tf.keras.models.Sequential()

# Add the first hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)


# Add the second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Add the third hidden layer
#nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Display the Sequential model summary
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 11)                132
#
#  dense_9 (Dense)             (None, 5)                 60
#
#  dense_10 (Dense)            (None, 1)                 6
#
# ...
# Total params: 198 (792.00 Byte)
# Trainable params: 198 (792.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model = nn.fit(X_train_scaled,y_train,epochs=50)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 3s 5ms/step - loss: 0.6448 - accuracy: 0.6646
# Epoch 2/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6328 - accuracy: 0.6646
# Epoch 3/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6222 - accuracy: 0.6959
# Epoch 4/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6133 - accuracy: 0.7053
# Epoch 5/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6044 - accuracy: 0.7179
# Epoch 6/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5964 - accuracy: 0.7116
# Epoch 7/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5897 - accuracy: 0.7085
# Epoch 8/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5823 - accuracy: 0.7116
# Epoch 9/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5762 - accuracy: 0.7179
# Epoch 10/50
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)

# Display the model loss and accuracy results
print(f"Model Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 40/40 - 0s - loss: 0.5229 - accuracy: 0.7367 - 411ms/epoch - 10ms/step
# Model Loss: 0.5229461193084717, Accuracy: 0.7367187738418579

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
file_path = Path("student_loans.keras")

# Export your model to a keras file
nn.save(file_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
file_path = Path("student_loans.keras")

# Load the model to a new object
nn_imported = tf.keras.models.load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = nn_imported.predict(X_test_scaled,verbose=2)

# Display a sample of the predictions
predictions[0:5]
# Out:
# 40/40 - 0s - 194ms/epoch - 5ms/step
# array([[0.44018656],
#        [0.41222763],
#        [0.61880064],
#        [0.5343964 ],
#        [0.98060644]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame(columns=["predictions"], data=predictions)
predictions_df["predictions"] = round(predictions_df["predictions"],0)
predictions_df
# Out:
#       predictions
# 0             0.0
# 1             0.0
# 2             1.0
# 3             1.0
# 4             1.0
# ...           ...
# 1275          0.0
# 1276          0.0
# 1277          0.0
# 1278          0.0
# 1279          0.0
#
# [1280 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, predictions_df["predictions"].values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.78      0.73       590
#            1       0.79      0.70      0.74       690
#
#     accuracy                           0.74      1280
#    macro avg       0.74      0.74      0.74      1280
# weighted avg       0.74      0.74      0.74      1280

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
# To build a recommendation system for student loan options, the following data would be necessary:
#
# - **Student Demographics**: Age, gender, and location. These factors can influence loan offers based on state-specific programs and financial needs.
#
# - **Academic Information**: School name, major, year of study, and GPA. Lenders may offer different terms based on the student’s academic performance and field of study.
#
# - **Financial Data**: Income, credit score, existing debts, and financial aid received. This helps in assessing the student’s ability to repay the loan.
# Loan Preferences: Desired loan amount, repayment period, and interest rate preferences. This ensures the recommendations align with the student's needs and preferences.
#
# - **Loan History**: Previous loans taken, repayment history, and current loan status. This is crucial for understanding the student’s borrowing behavior and creditworthiness.
#
# These data points are relevant and appropriate as they provide a comprehensive view of the student’s financial situation, academic standing, and personal preferences, allowing the recommendation system to offer tailored loan options.
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
# The model would primarily use **content-based filtering**. Content-based filtering uses the attributes of the users and items to make recommendations. Given the data such as demographics, academic information, financial data, loan preferences, and loan history, the system can match students with loan options that align with their specific characteristics and needs.
#
# Justification:
#
# - **Demographics and Academic Information**: Helps in identifying suitable loan programs based on location and field of study.
#
# - **Financial Data**: Essential for matching loan options that fit the student’s financial capacity.
#
# - **Loan Preferences and History**: Critical for recommending loans that align with the student’s borrowing behavior and repayment capabilities.
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
#
# - **Data Privacy and Security**: Handling sensitive financial and personal information requires robust security measures to protect against data breaches and ensure privacy compliance. This is a significant concern because any breach can lead to severe consequences for students, including identity theft and financial loss.
#
# - **Data Accuracy and Completeness**: Ensuring that the data collected is accurate, up-to-date, and complete can be challenging. Inaccurate or incomplete data can lead to inappropriate loan recommendations, which can negatively impact the student's financial situation and trust in the system. This is particularly concerning in student loans, where inaccurate assessments can burden students with unsuitable loan terms.
